# %%
import pandas as pd

# %%
ufo_data = pd.read_csv('http://bit.ly/uforeports')

# %%
chips_data = pd.read_csv('http://bit.ly/chiporders',sep='\t')

# %%
chips_data.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chips_data.tail(5)
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
ufo_data.head(5)
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# # Data Inspect

# %%
ufo_data.shape, chips_data.shape
# Out:
# ((18241, 5), (4622, 5))

# %%
ufo_data.info
# Out:
# <bound method DataFrame.info of                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# 18236  12/31/2000 23:00
# 18237  12/31/2000 23:00
# 18238  12/31/2000 23:45
# 18239  12/31/2000 23:45
# 18240  12/31/2000 23:59
#
# [18241 rows x 5 columns]>

# %%
chips_data.info
# Out:
# <bound method DataFrame.info of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]>

# %% [markdown]
# # Basic Statistics

# %%
chips_data.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
chips_data.describe(include='object')
# Out:
#            item_name choice_description item_price
# count           4622               3376       4622
# unique            50               1043         78
# top     Chicken Bowl        [Diet Coke]     $8.75
# freq             726                134        730

# %% [markdown]
# Accessing Columns

# %%
chips_data.item_name
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
chips_data['item_name']
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %% [markdown]
# Finding no.of unique values from each column

# %%
chips_data.nunique()
# Out:
# order_id              1834
# quantity                 9
# item_name               50
# choice_description    1043
# item_price              78
# dtype: int64

# %%
chips_data['item_name'].value_counts().head(5)
# Out:
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Steak Burrito          368
# Canned Soft Drink      301
# Name: item_name, dtype: int64

# %% [markdown]
# # Data Selection and Indexing

# %%
numeric_data = chips_data[['order_id','quantity']]

# %%
numeric_data.head(3)
# Out:
#    order_id  quantity
# 0         1         1
# 1         1         1
# 2         1         1

# %% [markdown]
# .loc[] ---> .loc[rows,columns]

# %%
chips_data.loc[3:6,['order_id','quantity']]
# Out:
#    order_id  quantity
# 3         1         1
# 4         2         2
# 5         3         1
# 6         3         1

# %%
chips_data.loc[100,'item_name']
# Out:
# 'Chips and Guacamole'

# %%
chips_data.loc[100,:]
# Out:
# order_id                               44
# quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 100, dtype: object

# %%
chips_data.loc[:,'item_name']
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
chips_data.iloc[1:4,0:2]
# Out:
#    order_id  quantity
# 1         1         1
# 2         1         1
# 3         1         1

# %% [markdown]
# # Indexing Methods

# %%
chips_data.set_index('order_id').head(3)
# Out:
#           quantity                     item_name choice_description item_price
# order_id
# 1                1  Chips and Fresh Tomato Salsa                NaN     $2.39
# 1                1                          Izze       [Clementine]     $3.39
# 1                1              Nantucket Nectar            [Apple]     $3.39

# %%
chips_data.set_index('order_id',inplace = True)

# %%
chips_data.head()
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
#
#                                          choice_description item_price
# order_id
# 1                                                       NaN     $2.39
# 1                                              [Clementine]     $3.39
# 1                                                   [Apple]     $3.39
# 1                                                       NaN     $2.39
# 2         [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chips_data.reset_index(inplace = True)

# %%
chips_data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# # Data Cleaning

# %%
chips_data.choice_description.isna()
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 4617    False
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# Name: choice_description, Length: 4622, dtype: bool

# %%
chips_data[chips_data.choice_description.isna()].head(5)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 6          3         1                          Side of Chips
# 10         5         1                    Chips and Guacamole
# 14         7         1                    Chips and Guacamole
#
#    choice_description item_price
# 0                 NaN     $2.39
# 3                 NaN     $2.39
# 6                 NaN     $1.69
# 10                NaN     $4.45
# 14                NaN     $4.45

# %%
chips_data.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chips_data.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
chips_data.choice_description.isna().sum()
# Out:
# 1246

# %% [markdown]
# # Fill the missing Data

# %%
ufo_data.isna().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
most_repeated = ufo_data['Shape Reported'].mode()[0]

# %%
most_repeated
# Out:
# 'LIGHT'

# %%
ufo_data.head(15)
# Out:
#                     City Colors Reported Shape Reported State  \
# 0                 Ithaca             NaN       TRIANGLE    NY
# 1            Willingboro             NaN          OTHER    NJ
# 2                Holyoke             NaN           OVAL    CO
# 3                Abilene             NaN           DISK    KS
# 4   New York Worlds Fair             NaN          LIGHT    NY
# 5            Valley City             NaN           DISK    ND
# 6            Crater Lake             NaN         CIRCLE    CA
# 7                   Alma             NaN           DISK    MI
# 8                Eklutna             NaN          CIGAR    AK
# 9                Hubbard             NaN       CYLINDER    OR
# 10               Fontana             NaN          LIGHT    CA
# 11              Waterloo             NaN       FIREBALL    AL
# 12                Belton             RED         SPHERE    SC
# 13                Keokuk             NaN           OVAL    IA
# 14             Ludington             NaN           DISK    MI
#
#                 Time
# 0     6/1/1930 22:00
# 1    6/30/1930 20:00
# 2    2/15/1931 14:00
# 3     6/1/1931 13:00
# 4    4/18/1933 19:00
# 5    9/15/1934 15:30
# 6     6/15/1935 0:00
# 7     7/15/1936 0:00
# 8   10/15/1936 17:00
# 9     6/15/1937 0:00
# 10   8/15/1937 21:00
# 11    6/1/1939 20:00
# 12   6/30/1939 20:00
# 13     7/7/1939 2:00
# 14    6/1/1941 13:00

# %%
ufo_data['Shape Reported'].isna().sum()
# Out:
# 2644

# %%
ufo_data['Shape Reported'].fillna(most_repeated,inplace=True)

# %%
ufo_data['Shape Reported'].isna().sum()
# Out:
# 0

# %%
ufo_data.isna().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported         0
# State                  0
# Time                   0
# dtype: int64

# %%
ufo_data.shape
# Out:
# (18241, 5)

# %%
ufo_data.dropna().head(3)
# Out:
#           City Colors Reported Shape Reported State             Time
# 12      Belton             RED         SPHERE    SC  6/30/1939 20:00
# 19  Bering Sea             RED          OTHER    AK  4/30/1943 23:00
# 36  Portsmouth             RED      FORMATION    VA   7/10/1945 1:30

# %%
ufo_data.isna().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported         0
# State                  0
# Time                   0
# dtype: int64

# %%
ufo_data.dropna(subset=['City']).head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo_data.dropna(subset=['City'],inplace=True)

# %%
ufo_data.shape
# Out:
# (18216, 5)

# %% [markdown]
# # Duplicates

# %%
chips_data.duplicated().sum()
# Out:
# 59

# %%
duplicates = chips_data[chips_data.duplicated()]

# %%
duplicates.head(3)
# Out:
#      order_id  quantity      item_name  \
# 238       103         1  Steak Burrito
# 248       108         1    Canned Soda
# 297       129         1  Steak Burrito
#
#                                     choice_description item_price
# 238  [Tomatillo Red Chili Salsa, [Rice, Black Beans...    $11.75
# 248                                     [Mountain Dew]     $1.09
# 297  [Tomatillo Green Chili Salsa, [Rice, Cheese, G...    $11.75

# %%
chips_data.drop_duplicates().head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chips_data.shape
# Out:
# (4622, 5)

# %%
chips_data.drop_duplicates().shape
# Out:
# (4563, 5)

# %%
chips_data.drop_duplicates(inplace=True)

# %%
chips_data.shape
# Out:
# (4563, 5)

# %% [markdown]
# # String Operations

# %%
data = {'Text':['Hello','World']}

# %%
dataframe = pd.DataFrame(data)

# %%
dataframe
# Out:
#     Text
# 0  Hello
# 1  World

# %%
dataframe['Text_upper'] = dataframe['Text'].str.upper()

# %%
dataframe
# Out:
#     Text Text_upper
# 0  Hello      HELLO
# 1  World      WORLD

# %%
dataframe['Contains_HELLO'] = dataframe['Text_upper'].str.contains('HELLO')

# %%
dataframe
# Out:
#     Text Text_upper  Contains_HELLO
# 0  Hello      HELLO            True
# 1  World      WORLD           False

# %%
chips_data.item_name
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4563, dtype: object

# %%
chips_data.item_name = chips_data.item_name.str.upper()

# %%
chips_data.item_name.str.contains('CHICKEN').sum()
# Out:
# 1540

# %%
chips_data.item_price
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4563, dtype: object

# %%
chips_data.item_price.str.replace('$','')
# Out:
# <ipython-input-79-829d4ecfc47f>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chips_data.item_price.str.replace('$','')
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4563, dtype: object

# %%
chips_data.item_price.str.replace('$','').astype('float')
# Out:
# <ipython-input-80-2a7c8a5cf34d>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chips_data.item_price.str.replace('$','').astype('float')
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4563, dtype: float64

# %%
chips_data.item_price = chips_data.item_price.str.replace('$','').astype('float')
# Out:
# <ipython-input-81-7bf74a9ac17c>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chips_data.item_price = chips_data.item_price.str.replace('$','').astype('float')

# %%
min_price = chips_data.item_price.min()
max_price = chips_data.item_price.max()

# %%
def normalize(x):
  return(x-min_price)/(max_price-min_price) # (2-1)/(10-1) = 1/9 = 0.1

# %%
normalized_price = chips_data.item_price.apply(normalize)

# %%
normalized_price
# Out:
# 0       0.030120
# 1       0.053290
# 2       0.053290
# 3       0.030120
# 4       0.368165
#           ...
# 4617    0.246988
# 4618    0.246988
# 4619    0.235403
# 4620    0.177479
# 4621    0.177479
# Name: item_price, Length: 4563, dtype: float64

# %%
data = {'A':[1,2,3,1,2], 'B':[4,5,3,2,6]}
df = pd.DataFrame(data)

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  3
# 3  1  2
# 4  2  6

# %%
def average_row(row):
  return row.mean()

# %%
df['Row_Average'] = df.apply(average_row,axis=1)

# %%
df
# Out:
#    A  B  Row_Average
# 0  1  4          2.5
# 1  2  5          3.5
# 2  3  3          3.0
# 3  1  2          1.5
# 4  2  6          4.0

# %%
mapping_dict = {1:'one', 2:'two', 3:'three'}
df['Encoded_A'] = df['A'].map(mapping_dict)

# %%
df
# Out:
#    A  B  Row_Average Encoded_A
# 0  1  4          2.5       one
# 1  2  5          3.5       two
# 2  3  3          3.0     three
# 3  1  2          1.5       one
# 4  2  6          4.0       two

# %%
data = {'A':[1,2,3], 'B':[4,5,6]}
df = pd.DataFrame(data)

# %%
def mul_10(x):
  return x*10

# %%
df = df.applymap(mul_10)

# %%
df
# Out:
#     A   B
# 0  10  40
# 1  20  50
# 2  30  60

# %%
chips_data['normalized_price'] = normalized_price

# %%
chips_data.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  CHIPS AND FRESH TOMATO SALSA                NaN
# 1         1         1                          IZZE       [Clementine]
# 2         1         1              NANTUCKET NECTAR            [Apple]
#
#    item_price  normalized_price
# 0        2.39           0.03012
# 1        3.39           0.05329
# 2        3.39           0.05329

# %%
ufo_data.head(3)
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo_data.drop(['Colors Reported'],axis=1,inplace=True)

# %%
ufo_data.head(3)
# Out:
#           City Shape Reported State             Time
# 0       Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke           OVAL    CO  2/15/1931 14:00
